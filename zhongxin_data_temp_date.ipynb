# %% [markdown]
# ## Pollutant Data from UCI Repository

# %%
import pandas as pd
from pandas.plotting import register_matplotlib_converters
register_matplotlib_converters()
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
#from datetime import datetime
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
# %matplotlib inline

dateparse = lambda x: pd.datetime.strptime(x, '%d/%m/%Y %H:%M') 
# Read data from file
data = pd.read_csv("zhongxin_data_2013_15.csv", usecols=['date', 'PM2_5', 'NO2', 'CO', 'TEMP'],
                   parse_dates=['date'], date_parser=dateparse) #, index_col='date')
data['date']=pd.to_datetime(data.date)
#data.set_index('date', inplace=True)

# Preview the data 
data.head()
# Out:
#                  date  PM2_5   NO2     CO  TEMP
# 0 2013-03-01 00:00:00    4.0   7.0  300.0  -0.7
# 1 2013-03-01 01:00:00    8.0   7.0  300.0  -1.1
# 2 2013-03-01 02:00:00    7.0  10.0  300.0  -1.1
# 3 2013-03-01 03:00:00    6.0  11.0  300.0  -1.4
# 4 2013-03-01 04:00:00    3.0  12.0  300.0  -2.0

# %%
# drop all rows with NaN
data = data.dropna()

# %%
sort = data.sort_values('date')

fig, ax = plt.subplots(figsize=(15,15))
ax.title.set_text('PM2.5, CO and Temperature against time')
ax.set_xlabel('Time')
ax.set_ylabel('Value')

ax.plot(sort.date, sort.PM2_5)
ax.plot(sort.date, sort.NO2)
ax.plot(sort.date, sort.TEMP)

# %%
X = np.array(date.dropna().values, dtype=float).reshape(-1, 1)
y = np.array(temp.dropna().values, dtype=float).reshape(-1, 1)

plt.figure(figsize=(15,10))
plt.scatter(X, y, color='red')
plt.title('Temperature and Time')
plt.xlabel('Time')
plt.ylabel('Temperature')
plt.show()

# %%
from scipy import optimize

def test_func(x, a, b):
    return a * np.sin(b * x)

import datetime as dt
data['date']= data['date'].map(dt.date.toordinal)


#data = data.dropna()
#date = data['date'].dt.strftime('%Y-%m-%d &H:%M%S')
#print(date)
date = data['date']
temp = data['TEMP']

params, params_covariance = optimize.curve_fit(test_func, date, temp,
                                               p0=[3, 3])

print(params)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-64-798825c40d45> in <module>
#       5
#       6 import datetime as dt
# ----> 7 data['date']= data['date'].map(dt.date.toordinal)
#       8
#       9
#
# ~\AppData\Roaming\Python\Python37\site-packages\pandas\core\series.py in map(self, arg, na_action)
#    3826         dtype: object
#    3827         """
# -> 3828         new_values = super()._map_values(arg, na_action=na_action)
#    3829         return self._constructor(new_values, index=self.index).__finalize__(self)
#    3830
#
# ~\AppData\Roaming\Python\Python37\site-packages\pandas\core\base.py in _map_values(self, mapper, na_action)
#    1298
#    1299         # mapper is a function
# -> 1300         new_values = map_f(values, mapper)
#    1301
#    1302         return new_values
#
# pandas/_libs/lib.pyx in pandas._libs.lib.map_infer()
#
# ...

# %%
plt.figure(figsize=(15, 10))
plt.scatter(date, temp, label='Data', color='red')
plt.plot(date, test_func(date, params[0], params[1]), label='Fitted function')
plt.legend(loc='best')
plt.show()
